# %% [markdown]
# <a href="https://colab.research.google.com/github/gianluigimazzaglia/SpeechGeneration_friends/blob/main/speech_generation_friends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn; cudnn.benchmark = True
import urllib

urllib.request.urlretrieve(
    'https://drive.google.com/uc?export=download&id=1f10Zoa_Lqg82-BnFLCHavVWig3Ei2fMV', 
    'script.txt'
    )
# Out:
# ('script.txt', <http.client.HTTPMessage at 0x7f6637a0a6d0>)

# %%
data_path = "script.txt"
batch_size = 8
batch_seq_len = 64
embed_size = 512
rnn_size = 1024

with open(data_path) as f:
    text = f.read()
text = text[180:]

token_dict = {".": "|fullstop|",
              ",": "|comma|",
              "\"": "|quote|",
              ";": "|semicolon|",
              "!": "|exclamation|",
              "?": "|question|",
              "(": "|leftparen|",
              ")": "|rightparen|",
              "--": "|dash|",
              "\n": "|newline|"
}
for punct, token in token_dict.items():
    text = text.replace(punct, f' {token} ')

text[:200]
# Out:
# "Monica: There's nothing to tell |exclamation|  He's just some guy I work with |exclamation|  |newline| Joey: C'mon |comma|  you're going out with the guy |exclamation|  There's gotta be something wron"

# %%
words = text.split(" ")
words = [word for word in words if len(word) > 0]
vocab = list(set(words))

for i, w in enumerate(vocab[:5]):
  print(i, w)
# Out:
# 0 Yeller
# 1 wouit
# 2 Burt
# 3 motional
# 4 mightve

# %%
vocab_to_int = {word: i for i,word in enumerate(vocab)}
int_to_vocab = {i: word for i,word in enumerate(vocab)}

num_words = len(vocab)
print(num_words)
# Out:
# 27750

# %%
print(len([word for word in text.split(" ") if len(word) > 0]))
# Out:
# 1207503

# %%
text_ints = [vocab_to_int[word] for word in text.split(" ") if len(word) > 0]
len(text_ints)
# Out:
# 1207503

# %%
import re
scene = re.findall(r'\[Scene.*?\]', text)
num_scenes = len(scene)
print(len(text_ints)/num_scenes)
# Out:
# 389.8944139489829

# %%
new_text = [word for word in text.split(" ") if len(word) > 0]
inputs = new_text[:5]
target = new_text[1:5]

print(inputs)
print(target)
# Out:
# ['Monica:', "There's", 'nothing', 'to', 'tell']
# ["There's", 'nothing', 'to', 'tell']

# %%
scene_length = 384

# %%
def get_batches(text_ints, scene_length, batch_size, batch_seq_len):
    num_scenes = len(text_ints)//scene_length
    text_targets = text_ints[1:] + [text_ints[0]]
    scene_inputs = [
                    text_ints[i * scene_length : (i+1) * scene_length] for i in 
                    range(num_scenes)
                    ]
    scene_targets = [
                     text_targets[i*scene_length:(i+1)*scene_length] for i in 
                     range(num_scenes)
                     ]
    num_mini_sequences = scene_length//batch_seq_len
    scene_inputs = [
                    [scene[i*batch_seq_len:(i+1)*batch_seq_len] for i in 
                     range(num_mini_sequences)] for scene in scene_inputs
                    ]
    scene_targets = [
                     [scene[i*batch_seq_len:(i+1)*batch_seq_len] for i in 
                      range(num_mini_sequences)] for scene in scene_targets
                     ]
    num_batch_groups = len(scene_inputs)//batch_size
    batches = []
    for i in range(num_batch_groups):
        group_scene_inputs = scene_inputs[i*batch_size:(i+1)*batch_size]
        group_scene_targets = scene_targets[i*batch_size:(i+1)*batch_size]
        for j in range(num_mini_sequences):
            reset_state = (j == 0)
            batch_inputs = torch.LongTensor(
                [group_scene_inputs[k][j] for k in range(batch_size)]
                )
            batch_targets = torch.LongTensor(
                [group_scene_targets[k][j] for k in range(batch_size)]
                )
            batches.append((reset_state, batch_inputs, batch_targets))
    return batches

# %%
batches = get_batches(text_ints, scene_length, batch_size, batch_seq_len)
batches[0][1].shape
# Out:
# torch.Size([8, 64])

# %%
script = [  int_to_vocab[y.item()] for y in [x for x in batches[1][1][3]] ]
script
# Out:
# ['me',
#  '|exclamation|',
#  '|newline|',
#  '|leftparen|',
#  'The',
#  'scene',
#  'on',
#  'TV',
#  'has',
#  'changed',
#  'to',
#  'show',
#  'two',
#  'women',
#  '|comma|',
#  'one',
#  'is',
#  'holding',
#  'her',
#  'hair',
#  '|fullstop|',
#  '|rightparen|',
#  '|newline|',
#  'Phoebe:',
#  'If',
#  'I',
#  'let',
#  'go',
#  'of',
#  'my',
#  'hair',
#  '|comma|',
#  'my',
#  'head',
#  'will',
#  'fall',
#  'off',
#  '|fullstop|',
#  '|newline|',
#  'Chandler:',
#  '|leftparen|',
#  're',
#  'TV',
#  '|rightparen|',
#  'Ooh',
#  '|comma|',
#  'she',
#  'should',
#  'not',
#  'be',
#  'wearing',
#  'those',
#  'pants',
#  '|fullstop|',
#  '|newline|',
#  'Joey:',
#  'I',
#  'say',
#  'push',
#  'her',
#  'down',
#  'the',
#  'stairs',
#  '|fullstop|']

# %%
class Model(nn.Module):
    
    def __init__(self, num_words, embed_size, rnn_size):
        super().__init__()
        self.rnn_size = rnn_size
        self.state = None
        self.embedding = nn.Embedding(num_words, embed_size)
        self.rnn = nn.LSTM(embed_size, rnn_size, batch_first=True)
        self.decoder = nn.Linear(rnn_size, num_words)
        self.reset_next_state = False
        
    def reset_state(self):
        self.reset_next_state = True
        
    def forward(self, x):
        if self.reset_next_state:
            self.state = (
                x.new_zeros(1, x.size(0), self.rnn_size).float(), 
                x.new_zeros(1, x.size(0), self.rnn_size).float())
            self.reset_next_state = False
        x = self.embedding(x)
        state = self.state if self.state is not None else None
        x, state = self.rnn(x, state)
        self.state = (state[0].data, state[1].data)
        x = self.decoder(x)
        return x

# %%
model = Model(num_words, embed_size, rnn_size)

# %%
# Setup device
dev = torch.device("cuda")

# %%
# Move model to device
model = model.to(dev)

# %%
# Define script generation function
def generate_script(model, seq_len, script_start):
    # Convert punctuaction in script start
    for punct, token in token_dict.items():
        script_start = script_start.replace(punct, f' {token} ')
    # Convert script start text to ints
    script_start = [vocab_to_int[word] for word in script_start.split(" ") if len(word) > 0]
    # Initialize output words/tokens
    script = script_start[:]
    # Convert script start to tensor (BxS = 1xS)
    script_start = torch.LongTensor(script_start).unsqueeze_(0)
    # Process script start and generate the rest of the script
    model.eval()
    model.reset_state()
    input = script_start
    for i in range(seq_len - script_start.size(1) + 1): # we include script_start as one of the generation steps
        # Copy input to device
        input = input.to(dev)
        # Pass to model
        output = model(input) # 1xSxV
        # Convert to word indexes
        words = output.max(2)[1] # 1xS
        words = words[0] # S
        # Add each word to script
        for j in range(words.size(0)):
            script.append(words[j].item())
        # Prepare next input
        input = torch.LongTensor([words[-1]]).unsqueeze(0) # 1xS = 1x1
    # Convert word indexes to text
    script = ' '.join([int_to_vocab[x] for x in script])
    # Convert punctuation tokens to symbols
    for punct,token in token_dict.items():
        script = script.replace(f"{token}", punct)
    # Return
    return script

# %%
generate_script(model, 20, "Phoebe: I can't believe this")
# Out:
# "Phoebe: I can't believe this trashy bang Jamie amazed SCOUT Crash $30 Yup Kung Hoyt wonderfully interns hitchhike Alan-ness Chinese Soaps Mississipily fling Scuse Changing"

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Initialize training history
loss_history = []
# Start training
for epoch in range(20):
    # Initialize accumulators for computing average loss/accuracy
    epoch_loss_sum = 0
    epoch_loss_cnt = 0
    # Set network mode
    model.train()
    # Process all batches
    for i,batch in enumerate(batches):
        # Parse batch
        reset_state, input, target = batch
        # Check reset state
        if reset_state:
            model.reset_state()
        # Move to device
        input = input.to(dev)
        target = target.to(dev)
        # Forward
        output = model(input)
        # Compute loss
        output = output.view(-1, num_words)
        target = target.view(-1)
        loss = F.cross_entropy(output, target)
        # Update loss sum
        epoch_loss_sum += loss.item()
        epoch_loss_cnt += 1
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # Shift sequence and recompute batches
    shift_point = random.randint(1, len(text_ints)-1)
    text_ints = text_ints[:shift_point] + text_ints[shift_point:]
    batches = get_batches(text_ints, scene_length, batch_size, batch_seq_len)
    # Epoch end - compute average epoch loss
    avg_loss = epoch_loss_sum/epoch_loss_cnt
    print(f"Epoch: {epoch+1}, loss: {epoch_loss_sum/epoch_loss_cnt:.4f}")
    print("Test sample:")
    print("---------------------------------------------------------------")
    print(generate_script(model, scene_length, "Ross:"))
    print("---------------------------------------------------------------")
    # Add to histories
    loss_history.append(avg_loss)
# Out:
# Epoch: 1, loss: 4.3085
# Test sample:
# ---------------------------------------------------------------
# Ross: ( to Ross ) : I don't know .
#  ( They hug . )
#  Ross: Oh , I can't believe you guys are gonna be able to get back together .
#  Ross: Oh , I don't know .
#  ( They hug . )
#  Ross: Oh , I love you .
#  ( They hug . )
#  Ross: Hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey , hey
# ---------------------------------------------------------------
# Epoch: 2, loss: 3.5830
# Test sample:
# ---------------------------------------------------------------
# Ross: Oh , I love you .
#  ( They hug . )
#  Ross: Oh my God !
#  Chandler: Oh my God !
#  Ross: Yeah , I love you .
#  ( She leaves the apartment . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love you .
#  ( She leaves . )
#  Chandler: Oh my God !
#  Ross: Oh my God !
#  ( Monica and Chandler are speechless )
#  Chandler: I love
# ---------------------------------------------------------------
# Epoch: 3, loss: 3.0909
# Test sample:
# ---------------------------------------------------------------
# Ross: Oh , I can't believe this . I can't believe you guys are gonna be here .
#  ( Rachel enters . )
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#  Ross: Hey !
#
# ---------------------------------------------------------------
# Epoch: 4, loss: 2.6770
# Test sample:
# ---------------------------------------------------------------
# Ross: No , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no ,
# ---------------------------------------------------------------
# Epoch: 5, loss: 2.3436
# Test sample:
# ---------------------------------------------------------------
# Ross: Oh , I don't know . Maybe I should .
#  Chandler: I know .
#  Ross: I know .
#  ( They hug . )
#  Ross: Okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , I have a little more . I mean , I have to get to know you guys . I love you . And I love you .
#  ( Ross enters with a huge plate of brown . )
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey
# ---------------------------------------------------------------
# Epoch: 6, loss: 2.0861
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , I know .
#  Rachel: I know .
#  Ross: I love you .
#  ( They hug . )
#  Ross: Okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , okay , gleba , gleba !
#  Erica: ( to Ross ) : Okay , okay .
#  ( She leaves the apartment . )
#
#  [Scene: The gate . Rachel walks up to the gate . ]
#  Rachel: Oh , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I know , I don't wanna be a little more comfortable .
#  Monica: Oh my God !
#  Chandler: Relax ! We'll just get her some antacids .
#  Monica: Oh , I don't know . Maybe I should .
#  Chandler: I know .
#  Monica: I know .
#  ( They hug )
#
#  [Scene: The hospital . Continued from earlier . ]
#  Rachel: I cannot believe this . I can't believe this . I mean , you have to get to know the baby , and I don't get to see him .
#  Monica: I don't know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  Monica: I know .
#  Chandler: I know .
#  ( They hug . )
#  Phoebe: Okay , well , I guess I have something I have
# ---------------------------------------------------------------
# Epoch: 7, loss: 1.8901
# Test sample:
# ---------------------------------------------------------------
# Ross: No , no , no . . . no .
#  ( Ross enters . )
#  Ross: Hey , Rach !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel:
# ---------------------------------------------------------------
# Epoch: 8, loss: 1.7442
# Test sample:
# ---------------------------------------------------------------
# Ross: No , no , no . . . no .
#  ( Ross enters . )
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
#  Ross: Hey .
# ---------------------------------------------------------------
# Epoch: 9, loss: 1.6343
# Test sample:
# ---------------------------------------------------------------
# Ross: No , no , no . . . no . . . no . . . no . . . no . . . no . . . no . . . no . . . no . . . hmmmmm . . .
#  Joey: Hey , hey . . .
#  Ross: Hey , hey , hey , hey .
#  Joey: Hey , hey , hey , hey , hey .
#  Ross: Hey , hey , hey , hey .
#  Joey: Hey , maybe I should just drop by .
#  Ross: Hey , I need a ticket .
#  Joey: Oh , yeah , yeah , yeah , sure , easy for you , you can drink .
#  Joey: Oh , yeah , yeah , sure .
#  ( Ross enters . )
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
#  Joey: Hey .
#  Ross: Hey .
# ---------------------------------------------------------------
# Epoch: 10, loss: 1.5544
# Test sample:
# ---------------------------------------------------------------
# Ross: No , no , no .
#  ( Monica and Chandler leave . )
#  Monica: Okay , let's see , who do you have a realtor ?
#  Phoebe: It's a cotton swab with a guy at the airport , and I didn't get to spend my day with you guys .
#  Chandler: I know . *He* always wanted to be the first black man to cross the Atlantic .
#  Phoebe: Oh my God !
#  Chandler: Relax ! We'll just get her some antacids .
#  Monica: Oh , I know .
#  Chandler: I know .
#  Monica: I know .
#  Rachel: I know . . . I know .
#  Phoebe: Yeah .
#  ( Chandler leans in . )
#  Chandler: I love you .
#  ( She leaves the apartment . )
#  Chandler: ( to the woman behind her ) This place is so depressing . There's something happen to me . I don't need any of your students , I can't do it .
#  Monica: Oh my God !
#  Chandler: Relax ! We'll just get her some antacids .
#  Monica: Oh , you know what ? You're right . I have a date tomorrow night .
#  Chandler: I know , I know . *He* always wanted to be the first black man to cross the Atlantic .
#  Phoebe: Oh , I know . I know . I know . I love you .
#  ( They hug . )
#  Rachel: I love you .
#  ( They hug . )
#  Phoebe: Okay , let's see .
#  ( She leaves the apartment . Joey has a " smile on his face )
#  Joey: Oh , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no . . . no . . . no .
# ---------------------------------------------------------------
# Epoch: 11, loss: 1.4944
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , yeah , yeah , yeah , yeah , yeah , yeah , sure , easy for you . . .
#  Rachel: Yeah .
#  Ross: I can't believe this .
#  Gate attendant #1: Madame , you gotta keep them short .
#  Rachel: Oh , I don't know .
#  Ross: You guys , you know what ? We have to talk to you about your options .
#  Chandler: I don't have a fax man .
#  Ross: Oh , I know . I know . I know . It's just , it's just . . . I love you .
#  ( They kiss again , and they kiss again . )
#
#  [Scene: The Hospital . Erica is moaning and about to see them . ]
#
#  Monica: Oh my God !
#  Chandler: Relax ! We'll just get her some antacids .
#  Monica: Oh , I know , I know , but , I don't know , I don't know . I mean , you know , I love you . I love you .
#  Chandler: I love you .
#  Monica: Oh my God .
#  Chandler: I know . *He* always wanted to be with someone else .
#  Monica: Yeah , and you know what ? This calls for a bottle of Israels finest .
#  Phoebe: ( to Joey ) You don't know military thing ?
#  Joey: I don't know . Maybe church-camp ?
#  Chandler: Hah . May not wanna mention this . So , you know ? I mean , I can see anything wrong with my boys .
#  Joey: Yeah , you know , it's great .
#  Chandler: Yeah , I mean , you know , I mean , you know , I mean , you know , you don't have to do this . I don't care if I don't get it .
#  Joey: I don't care , I don't know what to say . I mean , you know , you always cook , you know , you were-you , maybe you should talk .
#  Joey: Me too . I mean , you know , I mean , you know , I mean , you know , I
# ---------------------------------------------------------------
# Epoch: 12, loss: 1.4485
# Test sample:
# ---------------------------------------------------------------
# Ross: No , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no , no . . . no . . . no . . . no , no . . . no .
#  ( Ross looks very sad . )
#  Ross: Oh my God !
#  Rachel: What ?
#  Ross: I don't know why .
#  Rachel: Oh , I don't know , I don't know , I'm sorry , I didn't say goodbye to you because I didn't understand a singe word .
#  Ross: Yeah , I changed them .
#  Rachel: Oh , I know .
#  Ross: I know , but it's just so . . .
#  Chandler: Well , I guess there's nothing wrong with Emma !
#  Phoebe: Ok .
#  ( Ross starts to leave . )
#  Ross: What ?
#  Chandler: What ?
#  Ross: It's just a fur ball , you know .
#  Chandler: Oh , well , it's a shame that you-that you miss the movie 'cause we get to spend the next day .
#  Ross: Oh , right , right , right , right , right , right , right , right , right , right , right , right , right , right , right , well , now , now , now , now , now , and the director is just as it is . " Can I get to see ?
#  Mike: ( to Joey ) Good job , but I have to tell you something .
#  Joey: Alright , alright , alright . Calm , let's do it .
#  ( She leaves the apartment . Joey looks over his shoulders )
#  Joey: Oh , yeah , yeah , sure .
#  ( Joey leaves , and she's leaving with the room , they sit down )
#  Joey: Oh , oh , oh , and then she told the funniest guy she's leaving for you .
#  Phoebe: Oh , what are you ?
#  Joey: Oh , I don't know , I don't know what department that
# ---------------------------------------------------------------
# Epoch: 13, loss: 1.4141
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , yeah , yeah , yeah , yeah , sure , easy for you , you know , the first one you might be able to travel .
#  Rachel: Well , it doesn't matter . I mean , I have to get off the plane and she's the only one that she has her own .
#  Ross: Oh , oh , oh . . .
#  Phoebe: Yeah , but you don't have to do this .
#  Joey: I know , I know . I know . I know . I know . I know . I know . I know . I know . I know . I know . I know I speak being left out all day .
#  Rachel: Oh , really , really ?
#  Ross: Yeah .
#  Rachel: I mean , you know , maybe we can handle . Two's in the future , and we'll be able to get you some way back .
#  Ross: Oh , I can't believe you guys are leaving this .
#  Joey: Oh , oh .
#  Ross: Good !
#  ( They kiss . )
#
#  [Scene: The gate at the airport . Joey is still on the show . ]
#  Joey: Quack , quack , tweet , ok , then , then I call in the next room .
#  Monica: Oh my God !
#  Joey: Yeah .
#  Phoebe: I know , I know . I know . . . I know . . . I know . . . I know . . . I know . . . I know .
#  Joey: Me too . . . ( she looks likes he's in the back of the huge wall ) It's just as if . . .
#  ( Joey and Chandler all turn and look disapprovingly towards Monica but she just shrugs her . )
#  Chandler: Oh , yeah , yeah , yeah , sure , easy for you , you know , a bit of a love that is a tough sound to a very serious girl .
#  Joey: Oh , oh ! Maybe , maybe sleeping with the trophy !
#  Chandler: Oh , yeah , yeah , yeah , sure
# ---------------------------------------------------------------
# Epoch: 14, loss: 1.3978
# Test sample:
# ---------------------------------------------------------------
# Ross: Hey !
#  Phoebe: Hey !
#  Ross: Hey .
#  Rachel: Hey .
#  Phoebe: Hey !
#  Rachel: Hi !
#  Ross: Hey , you know what ? I was just doing here , right ?
#  Rachel: I don't know .
#  Ross: What ?
#  Rachel: You know what ? You're right , we are gonna have to tell her to do it .
#  Ross: Yeah , I'm sure .
#  Rachel: Oh , I can't say goodbye .
#  Ross: Oh my God .
#  Chandler: I know .
#  Ross: I mean , you know , you don't have to get her to go .
#  Chandler: Oh , well , we should probably call them .
#  Ross: Yeah , yeah , yeah . . .
#  Rachel: I mean , I know , but I don't think there is a reason that I sorta wasn't wrong about . . . I don't know . . . I don't know .
#  Ross: What ?
#  Rachel: You know what ? You know what ? You know what ? You know what ? You know what ? You are a very lucky , you're a terrible mother .
#  Ross: I know , but it's just that you know that you're wrong with all the sex lying , you know ? I mean , you know , maybe we should talk about that .
#  Rachel: Oh , you know what ? This calls for a bottle of Israels finest .
#  Ross: Oh my God !
#  Rachel: I know !
#  Ross: I can't believe this . This headhunter called me . It looks like you did !
#  Rachel: Well , it doesn't matter to me !
#  Ross: I can't believe this . This is her first birthday . And I know you love it .
#  Rachel: Oh , I know .
#  Ross: I love you .
#  ( They hug )
#
#  [Scene: The house next door to Chandler and Monica's new house . Chandler is pacing worriedly through the living room when Janice enters . ]
#  Chandler: Hey !
#  Monica: Hey !
#  Chandler: Hey !
#  Monica: Hey !
#  Chandler: Hey !
#
# ---------------------------------------------------------------
# Epoch: 15, loss: 1.3838
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , I know .
#  Rachel: I don't care .
#  Ross: I don't care .
#  Rachel: I don't know how to tell you this but Ross is right .
#  Phoebe: All right , let's see .
#  ( She leaves the apartment . Joey sighs )
#  Joey: Oh , I know , I'm pretty sure I was up all the way back .
#  ( Joey's dad the scene . )
#  Doctor: The baby's head is crowning .
#  ( Joey walks in . Supposedly Janice walks in )
#  Joey: Hey !
#  Chandler: Hey !
#  Joey: Hey !
#  Chandler: Hey .
#  Joey: Hey .
#  Chandler: Hey .
#  Joey: So . . . who's a good guy in the bathroom ?
#  Chandler: Yeah , yeah , yeah , yeah !
#  ( Joey walks in . )
#  Joey: Hey , hey , hey , hey , hey , hey , hey , hey , hey , hey . . .
#  Chandler: Hi , how was it ?
#  Joey: It's a scene from 1016 TOW Rachel's Going Away Party . Yes , that Bruce Willis from Moonlighting , but the food is sort of him . ]
#  Rachel: Okay .
#  Joey: Thank you .
#  ( He leaves the room , and they kiss . )
#  Chandler: You guys are gonna be great parents .
#  ( Monica enters carrying her son . )
#  Phoebe: Hey !
#  Monica: Hey .
#  Phoebe: Hey .
#  Monica: Hey .
#  Chandler: Hey .
#  Monica: Hey .
#  Chandler: Hey . Where've you been ?
#  Joey: Oh , I'm so excited , I know .
#  Chandler: Why ?
#  Monica: Oh , I'm sorry . . . Ella .
#  Phoebe: Oh , I can't believe you . I love you .
#  ( She kisses him passionately . )
#  Chandler: ( to the girls ) It's a woman !
#  Commercial Break
#  [Scene: The guest bedroom . Chandler and Monica are talking . ]
#  Chandler: I think this is the first time in my life right !
#  Monica: Oh , you did the right thing . Look ,
# ---------------------------------------------------------------
# Epoch: 16, loss: 1.3655
# Test sample:
# ---------------------------------------------------------------
# Ross: Hey !
#  Phoebe: Hey !
#  Joey: Hey .
#  Ross: Hey .
#  Joey: So . . . What . . . What do you say ?
#  Ross: Oh , I'm sorry . . . Ella .
#  Joey: Oh , hey , hey , hey . . .
#  ( They all walk over to the right )
#  Ross: What ? What ? What ?
#  Joey: You know , I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know . . . I don't know if you don't mind any of these , really , really , really , really , really , really , really , really , really long we're doing going to Paris .
#  Mr Zelner: Oh .
#  Ross: Yeah .
#  Joey: Oh . . . I love you .
#  ( They hug and kiss . )
#  Joey: Wait , wait , wait . . .
#  ( Rachel and Amy enter )
#  Rachel: Hi !
#  Joey: Hey !
#  Ross: Hey !
#  Joey: Hey !
#  Ross: Hey .
#  Joey: So , did you
# ---------------------------------------------------------------
# Epoch: 17, loss: 1.3610
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah ,
# ---------------------------------------------------------------
# Epoch: 18, loss: 1.3653
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , sure yeah ! I know ! I know ! I know . I know . It's an independent of a baby and I did it today .
#  Ross: Oh , I can't believe you guys are leaving this place .
#  Joey: Yeah , I know , I know , I know , and I know that you have it too .
#  ( Ross enters the room )
#  Everybody: Hey Rach , hey .
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey .
#  Rachel: So Pheebs , what are you doing here ?
#  Phoebe: Well , I was thinking that maybe we could hang out .
#  Rachel: Oh , okay .
#  ( They hug )
#
#
#  Rachel: Oh , I know , I know , isn't it the same thing you do ?
#  Ross: I don't know .
#  Rachel: Oh , I don't know , I'm sorry , I didn't tell you .
#  Ross: I know , and I didn't know what I'm gonna do .
#  Chandler: But I didn't come back today , they wouldn't have said anything .
#  Ross: So , what are you gonna do ?
#  Rachel: Well , I don't care . You can't be a friend of your best job .
#  Ross: Yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , sure , yeah I did . I actually think that too , isn't it ?
#  Rachel: Well , I don't know . . . I mean , you know , maybe if we just keep it at the agency .
#  Ross: Yeah , it's a shame that you-that you miss the movie that if ever been with . . .
#  Chandler: Oh my God !
#  Phoebe: Yeah ,
# ---------------------------------------------------------------
# Epoch: 19, loss: 1.3692
# Test sample:
# ---------------------------------------------------------------
# Ross: Yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , yeah , I don't mean . . .
#  Rachel: You know what ? This calls for a bottle of Israels finest .
#  Ross: Oh my God !
#  Chandler: Seriously , where did you get this ?
#  Ross: Mine .
#  Chandler: Oh , I don't know , I don't know . I mean , I , I mean , I mean , I mean , I mean , I mean , I mean , I mean , I mean , I mean , I mean , I just don't think I can get you a new job . You know , I mean , I mean , am I supposed to use this much ? I mean , this is what I want . I mean , I have won awards for my organizational skills . I mean , I have a cabin feeling or . . . I love you .
#  ( Ross enters the room )
#  Everybody: Hey you guys , you've been going out , huh ?
#  Joey: Oh , it wasn't great . It was just a kiss , but it was worth it ( He tries to kiss her again , but he clears , and Chandler and Monica arriving )
#  Rachel: ( on the other side of the line ) Okay .
#  Monica: Okay .
#  Chandler: Okay .
#  ( Monica and Chandler enter to look shocked . )
#  Chandler: I don't think she thinks I'm . . .
#  ( Monica is getting angry )
#  Monica: Hi !
#  Chandler: Hey !
#  Monica: Hey !
#  Chandler: Hey !
#  Monica: Hey !
#  Chandler: Hey !
#  Monica: Hey !
#  Chandler: Hey .
#  Monica: Hey .
#  Chandler: Hey .
#  Agency guy: So , these are the preliminary forms for an open adoption . There's a muffin and a boy , a beautiful woman is screaming and is in her frame . ]
#  Phoebe: Oh my God ! I can't believe they can they come here !
#  Monica: Oh God . . .
#  Phoebe: So , you just wanna
# ---------------------------------------------------------------
# Epoch: 20, loss: 1.3704
# Test sample:
# ---------------------------------------------------------------
# Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross: Hey !
#  Rachel: Hi !
#  Ross:
# ---------------------------------------------------------------

# %%
# Generate script
print(generate_script(model, scene_length, "Phoebe: I can't believe this"))
# Out:
# Phoebe: I can't believe this Wow have believe you . I can't believe you did this .
#  Monica: But what if it is , what happened ?
#  Ross: He was staring . This is where we're living under your wedding .
#  Erica: Wow ! Maybe , maybe she wouldnt mind about the little bit of our office .
#  Ross: Yeah , I mean , if you moved there , you get a lot of guys , you know , when I was younger . . . I don't know what you've got going this squirmy quality that I wrote in that place .
#  Rachel: Oh , well , that's right . I blocked that out .
#  Ross: Oh , no , no , no , no . . . I love you .
#  Rachel: Oh , I can't believe you guys are leaving a little child .
#  Ross: Oh my God .
#  Chandler: Yeah , I mean , you know , you know , you don't have a friend because you needed to make a special Valentines Day .
#  Ross: Oh , no !
#  Rachel: Well , I can't believe you did this .
#  Ross: I know , I know , I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . . . I know . It's a week .
#  Rachel: ( to Ross ) So , are you gonna change the last question so that I can make up ?
#  Ross: I don't know .
#  Rachel: You were so happy .
#  Ross: I know , I know . . . I know . . . I know . . . I know . . . I know . . . I know . .
